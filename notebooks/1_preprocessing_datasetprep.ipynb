# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/IE7500_GroupB/Dataset
# Out:
# /content/drive/MyDrive/IE7500_GroupB/Dataset

# %% [markdown]
# # Install Necessary Libraries

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.11/dist-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /usr/local/lib/python3.11/dist-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from gensim) (7.1.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open>=1.8.1->gensim) (1.17.2)

# %%
import pandas as pd
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from nltk.sentiment import SentimentIntensityAnalyzer

import gensim
import numpy as np

import plotly.graph_objects as go
from plotly.subplots import make_subplots

import plotly.express as px

import os

# Download NLTK dependencies
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")
nltk.download("vader_lexicon")
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# True

# %%
# Initialize components
stop_words = set(stopwords.words("english"))
lemmatizer = WordNetLemmatizer()
sia = SentimentIntensityAnalyzer()

# %% [markdown]
# # Load Dataset

# %%
import os
from pathlib import Path

# Load CSVs
df_analyst_processed = pd.read_csv("analyst_ratings_processed.csv", low_memory=False)
df_analyst_ratings = pd.read_csv("raw_analyst_ratings.csv", low_memory=False)
df_partner_headlines = pd.read_csv("raw_partner_headlines.csv", low_memory=False)

datasets = {
    "df_analyst_processed": df_analyst_processed,
    "df_analyst_ratings": df_analyst_ratings,
    "df_partner_headlines": df_partner_headlines
}

print("CSV files loaded successfully.")
# Out:
# CSV files loaded successfully.

# %%
print(df_analyst_processed.shape)
print(df_analyst_ratings.shape)
print(df_partner_headlines.shape)
# Out:
# (1400469, 4)
# (1407328, 6)
# (1845559, 6)

# %% [markdown]
# We are selecting to work with df_partner_headlines.csv dataset for our project as it has the most useful data for the purpose of our analysis.

# %% [markdown]
# # Dataset Preparation

# %%
import os
os.chdir('/content/drive/')

# %%
cd MyDrive/IE7500_GroupB/Notebooks
# Out:
# /content/drive/MyDrive/IE7500_GroupB/Notebooks

# %%
from helpers import *

# %%
# Tokenization
def tokenize(text):
    return word_tokenize(text)

# Normalize tokens (remove punctuation, symbols, etc.)
def normalize_tokens(tokens):
    return [re.sub(r"[^a-zA-Z0-9\s]", "", token.lower()) for token in tokens if token.isalnum()]

# Remove Stopwords
def remove_stopwords(tokens):
    return [word for word in tokens if word not in stop_words]

# Lemmatization
def lemmatize(tokens):
    return [lemmatizer.lemmatize(word) for word in tokens]


# Sentiment Analysis
def get_sentiment(text):
    return sia.polarity_scores(text)["compound"]

# Convert text into CountVectorizer (Bag of Words)
def apply_countvectorizer(texts):
    vectorizer = CountVectorizer()
    return vectorizer.fit_transform(texts), vectorizer

# Convert text into TF-IDF features
def apply_tfidf(texts):
    vectorizer = TfidfVectorizer()
    return vectorizer.fit_transform(texts), vectorizer

# %%
import spacy

# Load spaCy's English model
nlp = spacy.load("en_core_web_sm")

# %%
def get_pos_tags(text):
    doc = nlp(str(text))
    return [(token.text, token.pos_) for token in doc]

def get_named_entities(text):
    doc = nlp(str(text))
    return [(ent.text, ent.label_) for ent in doc.ents]

# %%
# Check for missing values
missing_values = df_partner_headlines.isnull().sum()

# Display only columns with missing values
missing_values[missing_values > 0]
# Out:
# Series([], dtype: int64)

# %%
# Check for Duplicates
duplicate_rows = df_partner_headlines.duplicated().sum()

# Display the count of duplicate rows
print(f"Number of duplicate rows: {duplicate_rows}")
# Out:
# Number of duplicate rows: 0

# %%
# Run Tokenization First on Headlines
text_column = "headline"
df_partner_headlines["tokens"] = df_partner_headlines[text_column].astype(str).apply(tokenize)
df_partner_headlines.head(5)
# Out:
#    Unnamed: 0                                           headline  \
# 0           2  Agilent Technologies Announces Pricing of $5……...
# 1           3  Agilent (A) Gears Up for Q2 Earnings: What's i...
# 2           4  J.P. Morgan Asset Management Announces Liquida...
# 3           5  Pershing Square Capital Management, L.P. Buys ...
# 4           6  Agilent Awards Trilogy Sciences with a Golden ...
#
#                                                  url  publisher  \
# 0  http://www.gurufocus.com/news/1153187/agilent-...  GuruFocus
# 1  http://www.zacks.com/stock/news/931205/agilent...      Zacks
# 2  http://www.gurufocus.com/news/1138923/jp-morga...  GuruFocus
# 3  http://www.gurufocus.com/news/1138704/pershing...  GuruFocus
# 4  http://www.gurufocus.com/news/1134012/agilent-...  GuruFocus
#
#                   date stock  \
# 0  2020-06-01 00:00:00     A
# 1  2020-05-18 00:00:00     A
# 2  2020-05-15 00:00:00     A
# 3  2020-05-15 00:00:00     A
# 4  2020-05-12 00:00:00     A
#
#                                               tokens
# 0  [Agilent, Technologies, Announces, Pricing, of...
# 1  [Agilent, (, A, ), Gears, Up, for, Q2, Earning...
# 2  [J.P., Morgan, Asset, Management, Announces, L...
# 3  [Pershing, Square, Capital, Management, ,, L.P...
# 4  [Agilent, Awards, Trilogy, Sciences, with, a, ...

# %%
# Normalize Tokens
df_partner_headlines["normalized_tokens"] = df_partner_headlines["tokens"].apply(normalize_tokens)
df_partner_headlines.head(5)
# Out:
#    Unnamed: 0                                           headline  \
# 0           2  Agilent Technologies Announces Pricing of $5……...
# 1           3  Agilent (A) Gears Up for Q2 Earnings: What's i...
# 2           4  J.P. Morgan Asset Management Announces Liquida...
# 3           5  Pershing Square Capital Management, L.P. Buys ...
# 4           6  Agilent Awards Trilogy Sciences with a Golden ...
#
#                                                  url  publisher  \
# 0  http://www.gurufocus.com/news/1153187/agilent-...  GuruFocus
# 1  http://www.zacks.com/stock/news/931205/agilent...      Zacks
# 2  http://www.gurufocus.com/news/1138923/jp-morga...  GuruFocus
# 3  http://www.gurufocus.com/news/1138704/pershing...  GuruFocus
# 4  http://www.gurufocus.com/news/1134012/agilent-...  GuruFocus
#
#                   date stock  \
# 0  2020-06-01 00:00:00     A
# 1  2020-05-18 00:00:00     A
# 2  2020-05-15 00:00:00     A
# 3  2020-05-15 00:00:00     A
# 4  2020-05-12 00:00:00     A
#
#                                               tokens  \
# 0  [Agilent, Technologies, Announces, Pricing, of...
# 1  [Agilent, (, A, ), Gears, Up, for, Q2, Earning...
# 2  [J.P., Morgan, Asset, Management, Announces, L...
# 3  [Pershing, Square, Capital, Management, ,, L.P...
# 4  [Agilent, Awards, Trilogy, Sciences, with, a, ...
#
#                                    normalized_tokens
# 0  [agilent, technologies, announces, pricing, of...
# 1  [agilent, a, gears, up, for, q2, earnings, wha...
# 2  [morgan, asset, management, announces, liquida...
# 3  [pershing, square, capital, management, buys, ...
# 4  [agilent, awards, trilogy, sciences, with, a, ...

# %%
# Remove Stopwords
df_partner_headlines["filtered_tokens"] = df_partner_headlines["normalized_tokens"].apply(remove_stopwords)
df_partner_headlines.head(5)
# Out:
#    Unnamed: 0                                           headline  \
# 0           2  Agilent Technologies Announces Pricing of $5……...
# 1           3  Agilent (A) Gears Up for Q2 Earnings: What's i...
# 2           4  J.P. Morgan Asset Management Announces Liquida...
# 3           5  Pershing Square Capital Management, L.P. Buys ...
# 4           6  Agilent Awards Trilogy Sciences with a Golden ...
#
#                                                  url  publisher  \
# 0  http://www.gurufocus.com/news/1153187/agilent-...  GuruFocus
# 1  http://www.zacks.com/stock/news/931205/agilent...      Zacks
# 2  http://www.gurufocus.com/news/1138923/jp-morga...  GuruFocus
# 3  http://www.gurufocus.com/news/1138704/pershing...  GuruFocus
# 4  http://www.gurufocus.com/news/1134012/agilent-...  GuruFocus
#
#                   date stock  \
# 0  2020-06-01 00:00:00     A
# 1  2020-05-18 00:00:00     A
# 2  2020-05-15 00:00:00     A
# 3  2020-05-15 00:00:00     A
# 4  2020-05-12 00:00:00     A
#
#                                               tokens  \
# 0  [Agilent, Technologies, Announces, Pricing, of...
# 1  [Agilent, (, A, ), Gears, Up, for, Q2, Earning...
# 2  [J.P., Morgan, Asset, Management, Announces, L...
# 3  [Pershing, Square, Capital, Management, ,, L.P...
# 4  [Agilent, Awards, Trilogy, Sciences, with, a, ...
#
#                                    normalized_tokens  \
# 0  [agilent, technologies, announces, pricing, of...
# 1  [agilent, a, gears, up, for, q2, earnings, wha...
# 2  [morgan, asset, management, announces, liquida...
# 3  [pershing, square, capital, management, buys, ...
# 4  [agilent, awards, trilogy, sciences, with, a, ...
#
#                                      filtered_tokens
# 0  [agilent, technologies, announces, pricing, mi...
# 1              [agilent, gears, q2, earnings, cards]
# 2  [morgan, asset, management, announces, liquida...
# 3  [pershing, square, capital, management, buys, ...
# 4  [agilent, awards, trilogy, sciences, golden, t...

# %%
# Run Lemmatization
df_partner_headlines["lemmas"] = df_partner_headlines["filtered_tokens"].apply(lemmatize)
df_partner_headlines.head(5)
# Out:
#    Unnamed: 0                                           headline  \
# 0           2  Agilent Technologies Announces Pricing of $5……...
# 1           3  Agilent (A) Gears Up for Q2 Earnings: What's i...
# 2           4  J.P. Morgan Asset Management Announces Liquida...
# 3           5  Pershing Square Capital Management, L.P. Buys ...
# 4           6  Agilent Awards Trilogy Sciences with a Golden ...
#
#                                                  url  publisher  \
# 0  http://www.gurufocus.com/news/1153187/agilent-...  GuruFocus
# 1  http://www.zacks.com/stock/news/931205/agilent...      Zacks
# 2  http://www.gurufocus.com/news/1138923/jp-morga...  GuruFocus
# 3  http://www.gurufocus.com/news/1138704/pershing...  GuruFocus
# 4  http://www.gurufocus.com/news/1134012/agilent-...  GuruFocus
#
#                   date stock  \
# 0  2020-06-01 00:00:00     A
# 1  2020-05-18 00:00:00     A
# 2  2020-05-15 00:00:00     A
# 3  2020-05-15 00:00:00     A
# 4  2020-05-12 00:00:00     A
#
#                                               tokens  \
# 0  [Agilent, Technologies, Announces, Pricing, of...
# 1  [Agilent, (, A, ), Gears, Up, for, Q2, Earning...
# 2  [J.P., Morgan, Asset, Management, Announces, L...
# 3  [Pershing, Square, Capital, Management, ,, L.P...
# 4  [Agilent, Awards, Trilogy, Sciences, with, a, ...
#
#                                    normalized_tokens  \
# 0  [agilent, technologies, announces, pricing, of...
# 1  [agilent, a, gears, up, for, q2, earnings, wha...
# 2  [morgan, asset, management, announces, liquida...
# 3  [pershing, square, capital, management, buys, ...
# 4  [agilent, awards, trilogy, sciences, with, a, ...
#
#                                      filtered_tokens  \
# 0  [agilent, technologies, announces, pricing, mi...
# 1              [agilent, gears, q2, earnings, cards]
# 2  [morgan, asset, management, announces, liquida...
# 3  [pershing, square, capital, management, buys, ...
# 4  [agilent, awards, trilogy, sciences, golden, t...
#
#                                               lemmas
# 0  [agilent, technology, announces, pricing, mill...
# 1                [agilent, gear, q2, earnings, card]
# 2  [morgan, asset, management, announces, liquida...
# 3  [pershing, square, capital, management, buy, a...
# 4  [agilent, award, trilogy, science, golden, tic...

# %%
# Run Sentiment Analysis
df_partner_headlines["sentiment_score"] = df_partner_headlines[text_column].astype(str).apply(get_sentiment)
df_partner_headlines.head(5)
# Out:
#    Unnamed: 0                                           headline  \
# 0           2  Agilent Technologies Announces Pricing of $5……...
# 1           3  Agilent (A) Gears Up for Q2 Earnings: What's i...
# 2           4  J.P. Morgan Asset Management Announces Liquida...
# 3           5  Pershing Square Capital Management, L.P. Buys ...
# 4           6  Agilent Awards Trilogy Sciences with a Golden ...
#
#                                                  url  publisher  \
# 0  http://www.gurufocus.com/news/1153187/agilent-...  GuruFocus
# 1  http://www.zacks.com/stock/news/931205/agilent...      Zacks
# 2  http://www.gurufocus.com/news/1138923/jp-morga...  GuruFocus
# 3  http://www.gurufocus.com/news/1138704/pershing...  GuruFocus
# 4  http://www.gurufocus.com/news/1134012/agilent-...  GuruFocus
#
#                   date stock  \
# 0  2020-06-01 00:00:00     A
# 1  2020-05-18 00:00:00     A
# 2  2020-05-15 00:00:00     A
# 3  2020-05-15 00:00:00     A
# 4  2020-05-12 00:00:00     A
#
#                                               tokens  \
# 0  [Agilent, Technologies, Announces, Pricing, of...
# 1  [Agilent, (, A, ), Gears, Up, for, Q2, Earning...
# 2  [J.P., Morgan, Asset, Management, Announces, L...
# 3  [Pershing, Square, Capital, Management, ,, L.P...
# 4  [Agilent, Awards, Trilogy, Sciences, with, a, ...
#
#                                    normalized_tokens  \
# 0  [agilent, technologies, announces, pricing, of...
# 1  [agilent, a, gears, up, for, q2, earnings, wha...
# 2  [morgan, asset, management, announces, liquida...
# 3  [pershing, square, capital, management, buys, ...
# 4  [agilent, awards, trilogy, sciences, with, a, ...
#
#                                      filtered_tokens  \
# 0  [agilent, technologies, announces, pricing, mi...
# 1              [agilent, gears, q2, earnings, cards]
# 2  [morgan, asset, management, announces, liquida...
# 3  [pershing, square, capital, management, buys, ...
# 4  [agilent, awards, trilogy, sciences, golden, t...
#
#                                               lemmas  sentiment_score
# 0  [agilent, technology, announces, pricing, mill...           0.0000
# 1                [agilent, gear, q2, earnings, card]           0.0000
# 2  [morgan, asset, management, announces, liquida...           0.3612
# 3  [pershing, square, capital, management, buy, a...           0.0000
# 4  [agilent, award, trilogy, science, golden, tic...           0.4588

# %% [markdown]
# ## Merge DataFrame with NASDAQ Stock Dataset

# %%
os.chdir('/content/drive/')

# %%
cd MyDrive/IE7500_GroupB/Dataset
# Out:
# /content/drive/MyDrive/IE7500_GroupB/Dataset

# %%
ticker_df = pd.read_csv('nasdaq_screener_1742264403037.csv')

# %%
ticker_df.head()
# Out:
#   Symbol                                               Name Last Sale  \
# 0      A             Agilent Technologies Inc. Common Stock   $121.18
# 1     AA                    Alcoa Corporation Common Stock     $33.53
# 2  AACBU                   Artius II Acquisition Inc. Units    $10.06
# 3   AACG   ATA Creativity Global American Depositary Shares   $0.9199
# 4   AACT  Ares Acquisition Corporation II Class A Ordina...    $11.15
#
#    Net Change % Change    Market Cap        Country  IPO Year   Volume  \
# 0      3.8500   3.281%  3.454875e+10  United States    1999.0  2978763
# 1      1.2200   3.776%  8.680392e+09  United States    2016.0  3837315
# 2      0.0000    0.00%  0.000000e+00  United States    2025.0        6
# 3     -0.0264   -2.79%  2.943692e+07          China    2008.0    23168
# 4     -0.0100   -0.09%  0.000000e+00            NaN    2023.0   135763
#
#         Sector                                          Industry
# 0  Industrials  Biotechnology: Laboratory Analytical Instruments
# 1  Industrials                                          Aluminum
# 2      Finance                                      Blank Checks
# 3  Real Estate                           Other Consumer Services
# 4      Finance                                      Blank Checks

# %%
# Merge the datasets on stock symbol
merged_df = df_partner_headlines.merge(
    ticker_df[['Symbol', 'Name', 'Market Cap', 'Country', 'IPO Year', 'Volume', 'Sector', 'Industry']],
    left_on='stock', right_on='Symbol', how='left'
)

# %%
merged_df.head()
# Out:
#    Unnamed: 0                                           headline  \
# 0           2  Agilent Technologies Announces Pricing of $5……...
# 1           3  Agilent (A) Gears Up for Q2 Earnings: What's i...
# 2           4  J.P. Morgan Asset Management Announces Liquida...
# 3           5  Pershing Square Capital Management, L.P. Buys ...
# 4           6  Agilent Awards Trilogy Sciences with a Golden ...
#
#                                                  url  publisher  \
# 0  http://www.gurufocus.com/news/1153187/agilent-...  GuruFocus
# 1  http://www.zacks.com/stock/news/931205/agilent...      Zacks
# 2  http://www.gurufocus.com/news/1138923/jp-morga...  GuruFocus
# 3  http://www.gurufocus.com/news/1138704/pershing...  GuruFocus
# 4  http://www.gurufocus.com/news/1134012/agilent-...  GuruFocus
#
#                   date stock  \
# 0  2020-06-01 00:00:00     A
# 1  2020-05-18 00:00:00     A
# 2  2020-05-15 00:00:00     A
# 3  2020-05-15 00:00:00     A
# 4  2020-05-12 00:00:00     A
#
#                                               tokens  \
# 0  [Agilent, Technologies, Announces, Pricing, of...
# 1  [Agilent, (, A, ), Gears, Up, for, Q2, Earning...
# 2  [J.P., Morgan, Asset, Management, Announces, L...
# 3  [Pershing, Square, Capital, Management, ,, L.P...
# 4  [Agilent, Awards, Trilogy, Sciences, with, a, ...
#
#                                    normalized_tokens  \
# 0  [agilent, technologies, announces, pricing, of...
# 1  [agilent, a, gears, up, for, q2, earnings, wha...
# 2  [morgan, asset, management, announces, liquida...
# 3  [pershing, square, capital, management, buys, ...
# 4  [agilent, awards, trilogy, sciences, with, a, ...
#
#                                      filtered_tokens  \
# 0  [agilent, technologies, announces, pricing, mi...
# 1              [agilent, gears, q2, earnings, cards]
# 2  [morgan, asset, management, announces, liquida...
# 3  [pershing, square, capital, management, buys, ...
# 4  [agilent, awards, trilogy, sciences, golden, t...
#
#                                               lemmas  sentiment_score Symbol  \
# 0  [agilent, technology, announces, pricing, mill...           0.0000      A
# 1                [agilent, gear, q2, earnings, card]           0.0000      A
# 2  [morgan, asset, management, announces, liquida...           0.3612      A
# 3  [pershing, square, capital, management, buy, a...           0.0000      A
# 4  [agilent, award, trilogy, science, golden, tic...           0.4588      A
#
#                                      Name    Market Cap        Country  \
# 0  Agilent Technologies Inc. Common Stock  3.454875e+10  United States
# 1  Agilent Technologies Inc. Common Stock  3.454875e+10  United States
# 2  Agilent Technologies Inc. Common Stock  3.454875e+10  United States
# 3  Agilent Technologies Inc. Common Stock  3.454875e+10  United States
# 4  Agilent Technologies Inc. Common Stock  3.454875e+10  United States
#
#    IPO Year     Volume       Sector  \
# 0    1999.0  2978763.0  Industrials
# 1    1999.0  2978763.0  Industrials
# 2    1999.0  2978763.0  Industrials
# 3    1999.0  2978763.0  Industrials
# 4    1999.0  2978763.0  Industrials
#
#                                            Industry
# 0  Biotechnology: Laboratory Analytical Instruments
# 1  Biotechnology: Laboratory Analytical Instruments
# 2  Biotechnology: Laboratory Analytical Instruments
# 3  Biotechnology: Laboratory Analytical Instruments
# 4  Biotechnology: Laboratory Analytical Instruments

# %%
# Drop redundant columns after merging
merged_df.drop(columns=['Unnamed: 0', 'Volume','Symbol'], inplace=True)

# %%
# Convert 'date' column to datetime
merged_df['date'] = pd.to_datetime(merged_df['date'])

# Extract Date Features
merged_df['year'] = merged_df['date'].dt.year
merged_df['month'] = merged_df['date'].dt.month
merged_df['day_of_week'] = merged_df['date'].dt.dayofweek

# %%
# Sentiment Classification (-1 Negative, 0 Neutral, 1 Positive)
merged_df['sentiment_label'] = merged_df['sentiment_score'].apply(lambda x: 1 if x > 0 else (-1 if x < 0 else 0))

# %%
# Text-Based Features
merged_df['headline_length'] = merged_df['headline'].apply(lambda x: len(str(x)))
merged_df['word_count'] = merged_df['headline'].apply(lambda x: len(str(x).split()))

# %%
# Apply classification
merged_df['Market_Cap_Category'] = merged_df['Market Cap'].apply(classify_market_cap)

# %%
merged_df.head()
# Out:
#                                             headline  \
# 0  Agilent Technologies Announces Pricing of $5……...
# 1  Agilent (A) Gears Up for Q2 Earnings: What's i...
# 2  J.P. Morgan Asset Management Announces Liquida...
# 3  Pershing Square Capital Management, L.P. Buys ...
# 4  Agilent Awards Trilogy Sciences with a Golden ...
#
#                                                  url  publisher       date  \
# 0  http://www.gurufocus.com/news/1153187/agilent-...  GuruFocus 2020-06-01
# 1  http://www.zacks.com/stock/news/931205/agilent...      Zacks 2020-05-18
# 2  http://www.gurufocus.com/news/1138923/jp-morga...  GuruFocus 2020-05-15
# 3  http://www.gurufocus.com/news/1138704/pershing...  GuruFocus 2020-05-15
# 4  http://www.gurufocus.com/news/1134012/agilent-...  GuruFocus 2020-05-12
#
#   stock                                             tokens  \
# 0     A  [Agilent, Technologies, Announces, Pricing, of...
# 1     A  [Agilent, (, A, ), Gears, Up, for, Q2, Earning...
# 2     A  [J.P., Morgan, Asset, Management, Announces, L...
# 3     A  [Pershing, Square, Capital, Management, ,, L.P...
# 4     A  [Agilent, Awards, Trilogy, Sciences, with, a, ...
#
#                                    normalized_tokens  \
# 0  [agilent, technologies, announces, pricing, of...
# 1  [agilent, a, gears, up, for, q2, earnings, wha...
# 2  [morgan, asset, management, announces, liquida...
# 3  [pershing, square, capital, management, buys, ...
# 4  [agilent, awards, trilogy, sciences, with, a, ...
#
#                                      filtered_tokens  \
# 0  [agilent, technologies, announces, pricing, mi...
# 1              [agilent, gears, q2, earnings, cards]
# 2  [morgan, asset, management, announces, liquida...
# 3  [pershing, square, capital, management, buys, ...
# 4  [agilent, awards, trilogy, sciences, golden, t...
#
#                                               lemmas  sentiment_score  ...  \
# 0  [agilent, technology, announces, pricing, mill...           0.0000  ...
# 1                [agilent, gear, q2, earnings, card]           0.0000  ...
# 2  [morgan, asset, management, announces, liquida...           0.3612  ...
# 3  [pershing, square, capital, management, buy, a...           0.0000  ...
# 4  [agilent, award, trilogy, science, golden, tic...           0.4588  ...
#
#   IPO Year       Sector                                          Industry  \
# 0   1999.0  Industrials  Biotechnology: Laboratory Analytical Instruments
# 1   1999.0  Industrials  Biotechnology: Laboratory Analytical Instruments
# 2   1999.0  Industrials  Biotechnology: Laboratory Analytical Instruments
# 3   1999.0  Industrials  Biotechnology: Laboratory Analytical Instruments
# 4   1999.0  Industrials  Biotechnology: Laboratory Analytical Instruments
#
#    year month day_of_week  sentiment_label  headline_length  word_count  \
# 0  2020     6           0                0               70          10
# 1  2020     5           0                0               58          11
# 2  2020     5           4                1               79          10
# 3  2020     5           4                0               99          14
# 4  2020     5           1                1               66          10
#
#    Market_Cap_Category
# 0                Large
# 1                Large
# 2                Large
# 3                Large
# 4                Large
#
# [5 rows x 23 columns]

# %% [markdown]
# score >= 0.5 → Buy
#
# score <= -0.5 → Sell
#
# -0.5 < score < 0.5 → Hold

# %%
def classify_recommendation(score):
    if score >= 0.5:
        return "Buy"
    elif score <= -0.5:
        return "Sell"
    else:
        return "Hold"

# %%
merged_df['recommendation'] = merged_df['sentiment_score'].apply(classify_recommendation)
merged_df.head()
# Out:
#                                             headline  \
# 0  Agilent Technologies Announces Pricing of $5……...
# 1  Agilent (A) Gears Up for Q2 Earnings: What's i...
# 2  J.P. Morgan Asset Management Announces Liquida...
# 3  Pershing Square Capital Management, L.P. Buys ...
# 4  Agilent Awards Trilogy Sciences with a Golden ...
#
#                                                  url  publisher       date  \
# 0  http://www.gurufocus.com/news/1153187/agilent-...  GuruFocus 2020-06-01
# 1  http://www.zacks.com/stock/news/931205/agilent...      Zacks 2020-05-18
# 2  http://www.gurufocus.com/news/1138923/jp-morga...  GuruFocus 2020-05-15
# 3  http://www.gurufocus.com/news/1138704/pershing...  GuruFocus 2020-05-15
# 4  http://www.gurufocus.com/news/1134012/agilent-...  GuruFocus 2020-05-12
#
#   stock                                             tokens  \
# 0     A  [Agilent, Technologies, Announces, Pricing, of...
# 1     A  [Agilent, (, A, ), Gears, Up, for, Q2, Earning...
# 2     A  [J.P., Morgan, Asset, Management, Announces, L...
# 3     A  [Pershing, Square, Capital, Management, ,, L.P...
# 4     A  [Agilent, Awards, Trilogy, Sciences, with, a, ...
#
#                                    normalized_tokens  \
# 0  [agilent, technologies, announces, pricing, of...
# 1  [agilent, a, gears, up, for, q2, earnings, wha...
# 2  [morgan, asset, management, announces, liquida...
# 3  [pershing, square, capital, management, buys, ...
# 4  [agilent, awards, trilogy, sciences, with, a, ...
#
#                                      filtered_tokens  \
# 0  [agilent, technologies, announces, pricing, mi...
# 1              [agilent, gears, q2, earnings, cards]
# 2  [morgan, asset, management, announces, liquida...
# 3  [pershing, square, capital, management, buys, ...
# 4  [agilent, awards, trilogy, sciences, golden, t...
#
#                                               lemmas  sentiment_score  ...  \
# 0  [agilent, technology, announces, pricing, mill...           0.0000  ...
# 1                [agilent, gear, q2, earnings, card]           0.0000  ...
# 2  [morgan, asset, management, announces, liquida...           0.3612  ...
# 3  [pershing, square, capital, management, buy, a...           0.0000  ...
# 4  [agilent, award, trilogy, science, golden, tic...           0.4588  ...
#
#         Sector                                          Industry  year  month  \
# 0  Industrials  Biotechnology: Laboratory Analytical Instruments  2020      6
# 1  Industrials  Biotechnology: Laboratory Analytical Instruments  2020      5
# 2  Industrials  Biotechnology: Laboratory Analytical Instruments  2020      5
# 3  Industrials  Biotechnology: Laboratory Analytical Instruments  2020      5
# 4  Industrials  Biotechnology: Laboratory Analytical Instruments  2020      5
#
#   day_of_week sentiment_label  headline_length  word_count  \
# 0           0               0               70          10
# 1           0               0               58          11
# 2           4               1               79          10
# 3           4               0               99          14
# 4           1               1               66          10
#
#    Market_Cap_Category  recommendation
# 0                Large            Hold
# 1                Large            Hold
# 2                Large            Hold
# 3                Large            Hold
# 4                Large            Hold
#
# [5 rows x 24 columns]

# %%
import os
os.chdir('/content/drive/')

# %%
cd MyDrive/IE7500_GroupB/Notebooks
# Out:
# /content/drive/MyDrive/IE7500_GroupB/Notebooks

# %% [markdown]
# Save DataFrame Checkpoint 1

# %%
# Save the merged DataFrame
merged_df.to_csv("saved_dfs/merged_df_v1.csv", index=False)

# %% [markdown]
# ## Apply Encoding to Categorical Columns

# %%
# Show all columns when printing DataFrames
pd.set_option('display.max_columns', None)

# %%
merged_df.head()
# Out:
#                                             headline  \
# 0  Agilent Technologies Announces Pricing of $5……...
# 1  Agilent (A) Gears Up for Q2 Earnings: What's i...
# 2  J.P. Morgan Asset Management Announces Liquida...
# 3  Pershing Square Capital Management, L.P. Buys ...
# 4  Agilent Awards Trilogy Sciences with a Golden ...
#
#                                                  url  publisher       date  \
# 0  http://www.gurufocus.com/news/1153187/agilent-...  GuruFocus 2020-06-01
# 1  http://www.zacks.com/stock/news/931205/agilent...      Zacks 2020-05-18
# 2  http://www.gurufocus.com/news/1138923/jp-morga...  GuruFocus 2020-05-15
# 3  http://www.gurufocus.com/news/1138704/pershing...  GuruFocus 2020-05-15
# 4  http://www.gurufocus.com/news/1134012/agilent-...  GuruFocus 2020-05-12
#
#   stock                                             tokens  \
# 0     A  [Agilent, Technologies, Announces, Pricing, of...
# 1     A  [Agilent, (, A, ), Gears, Up, for, Q2, Earning...
# 2     A  [J.P., Morgan, Asset, Management, Announces, L...
# 3     A  [Pershing, Square, Capital, Management, ,, L.P...
# 4     A  [Agilent, Awards, Trilogy, Sciences, with, a, ...
#
#                                    normalized_tokens  \
# 0  [agilent, technologies, announces, pricing, of...
# 1  [agilent, a, gears, up, for, q2, earnings, wha...
# 2  [morgan, asset, management, announces, liquida...
# 3  [pershing, square, capital, management, buys, ...
# 4  [agilent, awards, trilogy, sciences, with, a, ...
#
#                                      filtered_tokens  \
# 0  [agilent, technologies, announces, pricing, mi...
# 1              [agilent, gears, q2, earnings, cards]
# 2  [morgan, asset, management, announces, liquida...
# 3  [pershing, square, capital, management, buys, ...
# 4  [agilent, awards, trilogy, sciences, golden, t...
#
#                                               lemmas  sentiment_score  \
# 0  [agilent, technology, announces, pricing, mill...           0.0000
# 1                [agilent, gear, q2, earnings, card]           0.0000
# 2  [morgan, asset, management, announces, liquida...           0.3612
# 3  [pershing, square, capital, management, buy, a...           0.0000
# 4  [agilent, award, trilogy, science, golden, tic...           0.4588
#
#                                      Name    Market Cap        Country  \
# 0  Agilent Technologies Inc. Common Stock  3.454875e+10  United States
# 1  Agilent Technologies Inc. Common Stock  3.454875e+10  United States
# 2  Agilent Technologies Inc. Common Stock  3.454875e+10  United States
# 3  Agilent Technologies Inc. Common Stock  3.454875e+10  United States
# 4  Agilent Technologies Inc. Common Stock  3.454875e+10  United States
#
#    IPO Year       Sector                                          Industry  \
# 0    1999.0  Industrials  Biotechnology: Laboratory Analytical Instruments
# 1    1999.0  Industrials  Biotechnology: Laboratory Analytical Instruments
# 2    1999.0  Industrials  Biotechnology: Laboratory Analytical Instruments
# 3    1999.0  Industrials  Biotechnology: Laboratory Analytical Instruments
# 4    1999.0  Industrials  Biotechnology: Laboratory Analytical Instruments
#
#    year  month  day_of_week  sentiment_label  headline_length  word_count  \
# 0  2020      6            0                0               70          10
# 1  2020      5            0                0               58          11
# 2  2020      5            4                1               79          10
# 3  2020      5            4                0               99          14
# 4  2020      5            1                1               66          10
#
#   Market_Cap_Category recommendation
# 0               Large           Hold
# 1               Large           Hold
# 2               Large           Hold
# 3               Large           Hold
# 4               Large           Hold

# %% [markdown]
# Categorical Columns in Your DataFrame
# Here's a breakdown of what should be treated as categorical:
#
# Column Name	Reason
# publisher	Source of news → categorical text
# stock	Ticker symbol → categorical code
# Symbol	Same as stock, may be redundant
# Name	Company name → categorical
# Country	Country → clear categorical label
# Sector	Industry sector → categorical
# Industry	More specific business category
# Market_Cap_Category	Market cap class → categorical (ordinal-ish)
# recommendation	Target label (Buy/Hold/Sell) → categorical
# day_of_week	(0–6) but represents categories, not values
# month	Categorical when not modeling time series
# sentiment_label	-1, 0, 1 → considered a label/class

# %%
merged_df['publisher'].value_counts()
# Out:
# publisher
# Seeking Alpha                897219
# Zacks                        438107
# GuruFocus                    212433
# Investor's Business Daily    134890
# webmaster                     59669
# TalkMarkets                   27209
# Traders Huddle                16484
# TheStreet.Com                 16023
# Vetr                          10866
# Small Cap Network              8059
# Investopedia                   5455
# moneyshow                      4113
# BayStreet                      3511
# Marketfy Insights              3177
# Fox Business                   2770
# Accesswire                     2413
# ycharts                        2329
# msnmoney                        586
# Marketfy                        236
# Unknown                           9
# Born2Invest                       1
# Name: count, dtype: int64

# %%
merged_df['Country'].value_counts()
# Out:
# Country
# United States       828757
# Canada               44948
# China                17062
# Bermuda              10527
# Israel                8529
# United Kingdom        8127
# Brazil                7546
# Ireland               6320
# Switzerland           5421
# Netherlands           5269
# Greece                4431
# Luxembourg            3726
# India                 3527
# Taiwan                3296
# France                3102
# South Africa          3043
# Mexico                2814
# Japan                 2780
# Cayman Islands        2175
# Belgium               2109
# South Korea           1952
# Spain                 1829
# Argentina             1568
# Italy                 1260
# Australia             1194
# Chile                 1179
# Sweden                 932
# Hong Kong              925
# Panama                 889
# Monaco                 826
# Colombia               790
# Denmark                714
# Germany                707
# Puerto Rico            647
# Singapore              645
# Peru                   584
# Jersey                 512
# Guernsey               379
# Curacao                289
# Turkey                 204
# Marshall Islands       171
# Philippines            136
# Malaysia                79
# Macau                   58
# Indonesia               57
# Finland                  8
# Name: count, dtype: int64

# %%
merged_df['Sector'].value_counts()
# Out:
# Sector
# Consumer Discretionary    239511
# Finance                   176245
# Industrials               123234
# Technology                109439
# Health Care               105079
# Real Estate                59387
# Energy                     54333
# Utilities                  48253
# Consumer Staples           37869
# Basic Materials            25812
# Telecommunications         13305
# Miscellaneous               5902
# Name: count, dtype: int64

# %%
merged_df['Industry'].value_counts()
# Out:
# Industry
# Real Estate Investment Trusts                 54927
# Major Banks                                   42785
# Biotechnology: Pharmaceutical Preparations    38394
# Industrial Machinery/Components               37265
# Oil & Gas Production                          32588
#                                               ...
# Wholesale Distributors                          161
# Diversified Financial Services                  115
# Building operators                               82
# Professional and commerical equipment            52
# Consumer Electronics/Video Chains                 8
# Name: count, Length: 143, dtype: int64

# %%
merged_df['Market_Cap_Category'].value_counts()
# Out:
# Market_Cap_Category
# Nano      896614
# Large     426935
# Medium    265592
# Small     175382
# Micro      66424
# Mega       14612
# Name: count, dtype: int64

# %%
merged_df['sentiment_label'].value_counts()
# Out:
# sentiment_label
#  0    949171
#  1    600611
# -1    295777
# Name: count, dtype: int64

# %%
merged_df['recommendation'].value_counts()
# Out:
# recommendation
# Hold    1588489
# Buy      184563
# Sell      72507
# Name: count, dtype: int64

# %%
# One Hot Encode 'Market_Cap_Category' column
market_cap_ohe = pd.get_dummies(merged_df['Market_Cap_Category'], prefix="cap")

# Concatenate back to main DataFrame
merged_df = pd.concat([merged_df, market_cap_ohe], axis=1)

# %%
# One-hot encode 'Sector' column
sector_dummies = pd.get_dummies(merged_df['Sector'], prefix='sector')

# Concatenate the one-hot columns with the original DataFrame
merged_df = pd.concat([merged_df, sector_dummies], axis=1)

# %%
# Label Encode 'recommendation' column
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
merged_df['recommendation_label'] = le.fit_transform(merged_df['recommendation'])

# Mapping
recommendation_label_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
print(recommendation_label_mapping)
# Out:
# {'Buy': 0, 'Hold': 1, 'Sell': 2}

# %%
# Label encode 'Publisher' column
from sklearn.preprocessing import LabelEncoder


le = LabelEncoder()
merged_df['publisher_label'] = le.fit_transform(merged_df['publisher'])
# Mapping
publisher_label_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
print(publisher_label_mapping)
# Out:
# {'Accesswire': 0, 'BayStreet': 1, 'Born2Invest': 2, 'Fox Business': 3, 'GuruFocus': 4, 'Investopedia': 5, "Investor's Business Daily": 6, 'Marketfy': 7, 'Marketfy Insights': 8, 'Seeking Alpha': 9, 'Small Cap Network': 10, 'TalkMarkets': 11, 'TheStreet.Com': 12, 'Traders Huddle': 13, 'Unknown': 14, 'Vetr': 15, 'Zacks': 16, 'moneyshow': 17, 'msnmoney': 18, 'webmaster': 19, 'ycharts': 20}

# %%
# Label encode 'Country' column
from sklearn.preprocessing import LabelEncoder


le = LabelEncoder()
merged_df['country_label'] = le.fit_transform(merged_df['Country'])
# Mapping
country_label_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
print(country_label_mapping)
# Out:
# {'Argentina': 0, 'Australia': 1, 'Belgium': 2, 'Bermuda': 3, 'Brazil': 4, 'Canada': 5, 'Cayman Islands': 6, 'Chile': 7, 'China': 8, 'Colombia': 9, 'Curacao': 10, 'Denmark': 11, 'Finland': 12, 'France': 13, 'Germany': 14, 'Greece': 15, 'Guernsey': 16, 'Hong Kong': 17, 'India': 18, 'Indonesia': 19, 'Ireland': 20, 'Israel': 21, 'Italy': 22, 'Japan': 23, 'Jersey': 24, 'Luxembourg': 25, 'Macau': 26, 'Malaysia': 27, 'Marshall Islands': 28, 'Mexico': 29, 'Monaco': 30, 'Netherlands': 31, 'Panama': 32, 'Peru': 33, 'Philippines': 34, 'Puerto Rico': 35, 'Singapore': 36, 'South Africa': 37, 'South Korea': 38, 'Spain': 39, 'Sweden': 40, 'Switzerland': 41, 'Taiwan': 42, 'Turkey': 43, 'United Kingdom': 44, 'United States': 45, nan: 46}

# %%
# Label encode 'Industry' column
from sklearn.preprocessing import LabelEncoder


le = LabelEncoder()
merged_df['industry_label'] = le.fit_transform(merged_df['Industry'])
# Mapping
industry_label_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
print(industry_label_mapping)
# Out:
# {' Medicinal Chemicals and Botanical Products ': 0, 'Accident &Health Insurance': 1, 'Advertising': 2, 'Aerospace': 3, 'Agricultural Chemicals': 4, 'Air Freight/Delivery Services': 5, 'Aluminum': 6, 'Apparel': 7, 'Auto & Home Supply Stores': 8, 'Auto Manufacturing': 9, 'Auto Parts:O.E.M.': 10, 'Automotive Aftermarket': 11, 'Banks': 12, 'Beverages (Production/Distribution)': 13, 'Biotechnology: Biological Products (No Diagnostic Substances)': 14, 'Biotechnology: Commercial Physical & Biological Resarch': 15, 'Biotechnology: Electromedical & Electrotherapeutic Apparatus': 16, 'Biotechnology: In Vitro & In Vivo Diagnostic Substances': 17, 'Biotechnology: Laboratory Analytical Instruments': 18, 'Biotechnology: Pharmaceutical Preparations': 19, 'Blank Checks': 20, 'Books': 21, 'Broadcasting': 22, 'Building Materials': 23, 'Building Products': 24, 'Building operators': 25, 'Business Services': 26, 'Cable & Other Pay Television Services': 27, 'Catalog/Specialty Distribution': 28, 'Clothing/Shoe/Accessory Stores': 29, 'Coal Mining': 30, 'Commercial Banks': 31, 'Computer Communications Equipment': 32, 'Computer Manufacturing': 33, 'Computer Software: Prepackaged Software': 34, 'Computer Software: Programming Data Processing': 35, 'Computer peripheral equipment': 36, 'Construction/Ag Equipment/Trucks': 37, 'Consumer Electronics/Appliances': 38, 'Consumer Electronics/Video Chains': 39, 'Consumer Specialties': 40, 'Containers/Packaging': 41, 'Department/Specialty Retail Stores': 42, 'Diversified Commercial Services': 43, 'Diversified Financial Services': 44, 'EDP Services': 45, 'Electric Utilities: Central': 46, 'Electrical Products': 47, 'Electronic Components': 48, 'Electronics Distribution': 49, 'Engineering & Construction': 50, 'Environmental Services': 51, 'Farming/Seeds/Milling': 52, 'Finance Companies': 53, 'Finance/Investors Services': 54, 'Finance: Consumer Services': 55, 'Fluid Controls': 56, 'Food Chains': 57, 'Food Distributors': 58, 'Forest Products': 59, 'General Bldg Contractors - Nonresidential Bldgs': 60, 'Home Furnishings': 61, 'Homebuilding': 62, 'Hospital/Nursing Management': 63, 'Hotels/Resorts': 64, 'Industrial Machinery/Components': 65, 'Industrial Specialties': 66, 'Integrated oil Companies': 67, 'Investment Bankers/Brokers/Service': 68, 'Investment Managers': 69, 'Life Insurance': 70, 'Major Banks': 71, 'Major Chemicals': 72, 'Marine Transportation': 73, 'Meat/Poultry/Fish': 74, 'Medical Electronics': 75, 'Medical Specialities': 76, 'Medical/Dental Instruments': 77, 'Medical/Nursing Services': 78, 'Metal Fabrications': 79, 'Metal Mining': 80, 'Military/Government/Technical': 81, 'Mining & Quarrying of Nonmetallic Minerals (No Fuels)': 82, 'Misc Corporate Leasing Services': 83, 'Misc Health and Biotechnology Services': 84, 'Miscellaneous manufacturing industries': 85, 'Motor Vehicles': 86, 'Movies/Entertainment': 87, 'Multi-Sector Companies': 88, 'Natural Gas Distribution': 89, 'Newspapers/Magazines': 90, 'Office Equipment/Supplies/Services': 91, 'Oil & Gas Production': 92, 'Oil Refining/Marketing': 93, 'Oil/Gas Transmission': 94, 'Oilfield Services/Equipment': 95, 'Ophthalmic Goods': 96, 'Ordnance And Accessories': 97, 'Other Consumer Services': 98, 'Other Metals and Minerals': 99, 'Other Pharmaceuticals': 100, 'Other Specialty Stores': 101, 'Package Goods/Cosmetics': 102, 'Packaged Foods': 103, 'Paints/Coatings': 104, 'Paper': 105, 'Plastic Products': 106, 'Pollution Control Equipment': 107, 'Power Generation': 108, 'Precious Metals': 109, 'Precision Instruments': 110, 'Professional Services': 111, 'Professional and commerical equipment': 112, 'Property-Casualty Insurers': 113, 'Publishing': 114, 'RETAIL: Building Materials': 115, 'Radio And Television Broadcasting And Communications Equipment': 116, 'Railroads': 117, 'Real Estate': 118, 'Real Estate Investment Trusts': 119, 'Recreational Games/Products/Toys': 120, 'Rental/Leasing Companies': 121, 'Restaurants': 122, 'Retail-Auto Dealers and Gas Stations': 123, ' ...

# %%
merged_df.shape
# Out:
# (1845559, 46)

# %%
# Save the merged DataFrame
merged_df.to_csv("saved_dfs/df_for_models.csv", index=False)

# %%
merged_df.dtypes
# Out:
# headline                                 object
# url                                      object
# publisher                                object
# date                             datetime64[ns]
# stock                                    object
# tokens                                   object
# normalized_tokens                        object
# filtered_tokens                          object
# lemmas                                   object
# sentiment_score                         float64
# Name                                     object
# Market Cap                              float64
# Country                                  object
# IPO Year                                float64
# Sector                                   object
# Industry                                 object
# year                                      int32
# month                                     int32
# day_of_week                               int32
# sentiment_label                           int64
# headline_length                           int64
# word_count                                int64
# Market_Cap_Category                      object
# recommendation                           object
# cap_Large                                  bool
# cap_Medium                                 bool
# cap_Mega                                   bool
# cap_Micro                                  bool
# cap_Nano                                   bool
# cap_Small                                  bool
# sector_Basic Materials                     bool
# sector_Consumer Discretionary              bool
# sector_Consumer Staples                    bool
# sector_Energy                              bool
# sector_Finance                             bool
# sector_Health Care                         bool
# sector_Industrials                         bool
# sector_Miscellaneous                       bool
# sector_Real Estate                         bool
# sector_Technology                          bool
# sector_Telecommunications                  bool
# sector_Utilities                           bool
# recommendation_label                      int64
# publisher_label                           int64
# country_label                             int64
# industry_label                            int64
# dtype: object

# %%
# Convert data types to dictionary
dtypes_dict = merged_df.dtypes.apply(lambda x: x.name).to_dict()

# View or print the result
print(dtypes_dict)
# Out:
# {'headline': 'object', 'url': 'object', 'publisher': 'object', 'date': 'datetime64[ns]', 'stock': 'object', 'tokens': 'object', 'normalized_tokens': 'object', 'filtered_tokens': 'object', 'lemmas': 'object', 'sentiment_score': 'float64', 'Name': 'object', 'Market Cap': 'float64', 'Country': 'object', 'IPO Year': 'float64', 'Sector': 'object', 'Industry': 'object', 'year': 'int32', 'month': 'int32', 'day_of_week': 'int32', 'sentiment_label': 'int64', 'headline_length': 'int64', 'word_count': 'int64', 'Market_Cap_Category': 'object', 'recommendation': 'object', 'cap_Large': 'bool', 'cap_Medium': 'bool', 'cap_Mega': 'bool', 'cap_Micro': 'bool', 'cap_Nano': 'bool', 'cap_Small': 'bool', 'sector_Basic Materials': 'bool', 'sector_Consumer Discretionary': 'bool', 'sector_Consumer Staples': 'bool', 'sector_Energy': 'bool', 'sector_Finance': 'bool', 'sector_Health Care': 'bool', 'sector_Industrials': 'bool', 'sector_Miscellaneous': 'bool', 'sector_Real Estate': 'bool', 'sector_Technology': 'bool', 'sector_Telecommunications': 'bool', 'sector_Utilities': 'bool', 'recommendation_label': 'int64', 'publisher_label': 'int64', 'country_label': 'int64', 'industry_label': 'int64'}

# %%
# save df datatypes to ensure data integrity
merged_df.dtypes.to_csv('saved_dfs/merged_df_dict.csv')
